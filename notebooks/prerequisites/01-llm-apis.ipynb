# %% [markdown]
# ### Load Environment

# %%
from dotenv import load_dotenv
import os

load_dotenv("../../.env")

OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")
GOOGLE_API_KEY = os.getenv("GOOGLE_API_KEY")
GROQ_API_KEY = os.getenv("GROQ_API_KEY")

# %% [markdown]
# ### OpenAI Client

# %%
from openai import OpenAI

client = OpenAI(api_key=OPENAI_API_KEY)

response = client.chat.completions.create(
    model="gpt-5-nano",
    messages=[
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": "Can you print 10 random words?"},
    ],
)

print(response.choices[0].message.content)
# Out:
# lighthouse zephyr ember velvet marigold kettle comet canyon ripple atlas

# %%
response.usage
# Out:
# CompletionUsage(completion_tokens=728, prompt_tokens=24, total_tokens=752, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=704, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0))

# %%
response = client.chat.completions.create(
    model="gpt-5-nano",
    messages=[
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": "Can you print 10 random words?"},
    ],
    reasoning_effort="minimal",
)

print(response.choices[0].message.content)
# Out:
# Sure. Here are 10 random words:
#
# 1. Lantern
# 2. Mosaic
# 3. Whisper
# 4. Fjord
# 5. Velvet
# 6. Compass
# 7. Quarry
# 8. Bristle
# 9. Echo
# 10. Jubilant

# %%
response.usage
# Out:
# CompletionUsage(completion_tokens=60, prompt_tokens=24, total_tokens=84, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0))

# %% [markdown]
# ### Google GenAI Client

# %%
from google import genai

gemini_client = genai.Client(api_key=GOOGLE_API_KEY)
response = gemini_client.models.generate_content(
    model="gemini-2.5-flash",
    contents=["You are a helpful assistant.", "Can you print 10 random words?"], # Contents = system + user messages
)

print(response.text)
# Out:
# Here are 10 random words:
#
# 1.  **Galaxy**
# 2.  **Whisper**
# 3.  **Journey**
# 4.  **Crimson**
# 5.  **Anchor**
# 6.  **Serenity**
# 7.  **Quasar**
# 8.  **Echo**
# 9.  **Vortex**
# 10. **Luminous**

# %% [markdown]
# ### Groq Client
#
# superfast interence speeds - ( Low Reasoning tasks )

# %%
from groq import Groq

groq_client = Groq(api_key=GROQ_API_KEY)


try:
    resp = groq_client.chat.completions.create(
        model="llama-3.3-70b-versatile",
        messages=[
            {"role": "system", "content": "You are a helpful assistant."},
            {"role": "user", "content": "Can you print 10 random words?"},
        ]
    )
    print(resp.choices[0].message.content)
except Exception as e:
    print("Groq error:", repr(e))
# Out:
# Here are 10 random words:
#
# 1. Mango
# 2. Space
# 3. Helicopter
# 4. Coffee
# 5. Bicycle
# 6. Dragon
# 7. Pineapple
# 8. Guitar
# 9. Snowflake
# 10. Starfish
