# %% [markdown]
# ### Load Environment

# %%
# Out:
# The kernel failed to start as the Python Environment 'agentic-ai-swirlai (Python 3.13.11)' is no longer available. Consider selecting another kernel or refreshing the list of Python Environments.

# %%
from dotenv import load_dotenv
import os

load_dotenv("../../.env")

OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")
GOOGLE_API_KEY = os.getenv("GOOGLE_API_KEY")
GROQ_API_KEY = os.getenv("GROQ_API_KEY")

# %% [markdown]
# ### OpenAI Client

# %%
import openai


response = openai.chat.completions.create(
    model="gpt-5-nano",
    messages=[
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": "Can you print 10 random words?"},
    ],
)

print(response.choices[0].message.content)
# Out:
# arcade quiver buttercup nebula tangle marigold pylon glacier zephyr lantern

# %%
response.usage

# %%
response = openai.chat.completions.create(
    model="gpt-5-nano",
    messages=[
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": "Can you print 10 random words?"},
    ],
    reasoning_effort="minimal",
)

print(response.choices[0].message.content)

# %%
response.usage

# %% [markdown]
# ### Google GenAI Client

# %%
from google import genai

gemini_client = genai.Client(api_key=GOOGLE_API_KEY)
response = gemini_client.models.generate_content(
    model="gemini-2.5-flash",
    contents=["You are a helpful assistant.", "Can you print 10 random words?"], # Contents = system + user messages
)

print(response.text)

# %% [markdown]
# ### Groq Client
#
# superfast interence speeds - ( Low Reasoning tasks )

# %%
from groq import Groq

client = Groq(api_key=GROQ_API_KEY)

chat_completion = client.chat.completions.create(
    model="llama-3.3-70b-versatile",
    messages=[
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": "Can you print 10 random words?"},
    ],
)

print(chat_completion.choices[0].message.content)
